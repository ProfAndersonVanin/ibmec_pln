# %% [markdown]
# # 🧪 Atividade de Laboratório — Aula 1
# ## Representações Conceituais de Palavras
#
# ---
#
# | | |
# |---|---|
# | **Disciplina** | Processamento de Linguagem Natural |
# | **Aula** | 1 — Ontologias, Grafos de Conhecimento, WordNet e BabelNet |
# | **Tempo estimado** | 50 minutos |
# | **Modalidade** | Individual |
#
# ---
#
# ## 📋 Instruções Gerais
#
# - Execute as células de **Configuração Inicial** antes de começar
# - Leia atentamente o enunciado de cada tarefa antes de escrever o código
# - Escreva seu código **apenas nas células indicadas** com `# ✏️ SEU CÓDIGO AQUI`
# - Não apague os comentários de orientação
# - Ao concluir, salve o notebook com o nome: `lab01_SEU_NOME.ipynb`
#
# > 💡 **Dica:** Consulte os exemplos da Aula 1 sempre que precisar de referência.
#
# ---

# %% [markdown]
# ## ⚙️ Configuração Inicial
# **Execute esta célula primeiro. Não modifique seu conteúdo.**

# %%
# ─────────────────────────────────────────────────────────────
# CONFIGURAÇÃO INICIAL — execute antes de começar as tarefas
# ─────────────────────────────────────────────────────────────

import nltk
import networkx as nx
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

nltk.download('wordnet', quiet=True)
nltk.download('omw-1.4', quiet=True)

from nltk.corpus import wordnet as wn

# Identificação do aluno
NOME_ALUNO = ""  # ← Digite seu nome entre as aspas

if NOME_ALUNO.strip() == "":
    print("⚠️  Atenção: preencha seu nome na variável NOME_ALUNO acima!")
else:
    print(f"✅ Ambiente pronto!")
    print(f"👤 Aluno: {NOME_ALUNO}")
    print(f"📘 Lab 01 — Representações Conceituais de Palavras")

# %% [markdown]
# ---
# ## 🎯 Contexto da Atividade
#
# Você foi contratado como desenvolvedor júnior de PLN em uma empresa de tecnologia.
# Seu primeiro projeto é construir um **Explorador Semântico** — uma ferramenta que analisa
# palavras e descobre automaticamente seus significados, relações e similaridades.
#
# O projeto é dividido em **4 tarefas progressivas**, cada uma adicionando uma nova
# funcionalidade ao explorador.
#
# ---

# %% [markdown]
# ## 📌 Tarefa 1 — Identificador de Significados
# **Tempo sugerido: 10 minutos | Valor: 25 pontos**
#
# ### Enunciado
#
# A primeira funcionalidade do Explorador Semântico é identificar
# todos os **significados possíveis** de uma palavra.
#
# Escreva um código que, dada a palavra `'light'`, faça o seguinte:
#
# 1. Liste **todos os synsets** da palavra
# 2. Para cada synset, exiba:
#    - O **nome** do synset (ex: `light.n.01`)
#    - A **categoria gramatical** — se é substantivo (`n`), verbo (`v`) ou adjetivo (`s`/`a`)
#    - A **definição** em inglês
#    - Os **sinônimos** (lemas)
# 3. Ao final, exiba **quantos significados** a palavra possui no total
#
# **Saída esperada (exemplo parcial):**
# ```
# 🔍 Explorando: "light"
# ──────────────────────────────────────
# Synset 1: light.n.01
#   Categoria  : substantivo
#   Definição  : (electromagnetic radiation...)
#   Sinônimos  : ['light', 'visible_light']
# ...
# ──────────────────────────────────────
# Total de significados: X
# ```
#
# > 💡 **Dica:** use `synset.pos()` para obter a categoria gramatical (`'n'`, `'v'`, `'a'`, `'s'`)

# %%
# ✏️ SEU CÓDIGO AQUI — Tarefa 1
# ─────────────────────────────────────────────────────────────
# Dica 1: synsets = wn.synsets('light')
# Dica 2: para categoria → synset.pos() retorna 'n', 'v', 'a' ou 's'
# Dica 3: mapeie 'n' → 'substantivo', 'v' → 'verbo', etc.
# Dica 4: para sinônimos → [l.name() for l in synset.lemmas()]
# ─────────────────────────────────────────────────────────────

# %% [markdown]
# ---
# ## 📌 Tarefa 2 — Navegador de Hierarquia
# **Tempo sugerido: 10 minutos | Valor: 25 pontos**
#
# ### Enunciado
#
# A segunda funcionalidade é o **Navegador de Hierarquia** — ela mostra
# como um conceito se encaixa no universo de conhecimento do WordNet.
#
# Escolha **uma das palavras abaixo** (ou sugira uma ao professor) e escreva um código que:
#
# ```
# Opções: 'ocean', 'guitar', 'doctor', 'computer', 'flower'
# ```
#
# 1. Trabalhe com o **primeiro synset** da palavra escolhida
# 2. Exiba os **hypernyms** (conceitos mais gerais)
# 3. Exiba os **hyponyms** (conceitos mais específicos) — limite a 5
# 4. Exiba os **meronyms** (partes do conceito), se existirem
# 5. Mostre o **caminho completo** da palavra até o topo da hierarquia,
#    usando indentação para representar cada nível
#
# **Saída esperada (exemplo com 'guitar'):**
# ```
# 🎸 Navegando: guitar.n.01
# Definição: a stringed instrument...
#
# 📈 Hypernyms (mais geral):
#    → stringed_instrument.n.01
#
# 📉 Hyponyms (mais específico):
#    → acoustic_guitar.n.01
#    → electric_guitar.n.01
#
# 🌳 Hierarquia completa:
# entity.n.01
#   └─ object.n.01
#        └─ ...
#             └─ guitar.n.01
# ```
#
# > 💡 **Dica:** use `enumerate()` e multiplicação de string para criar a indentação:
# > `'  ' * nivel` gera espaços proporcionais ao nível

# %%
# ✏️ SEU CÓDIGO AQUI — Tarefa 2
# ─────────────────────────────────────────────────────────────
# Dica 1: palavra = 'ocean'  ← troque pela sua escolha
# Dica 2: syn = wn.synsets(palavra)[0]
# Dica 3: syn.hypernyms() | syn.hyponyms() | syn.part_meronyms()
# Dica 4: syn.hypernym_paths()[0] → lista do topo até o synset
# ─────────────────────────────────────────────────────────────

# %% [markdown]
# ---
# ## 📌 Tarefa 3 — Comparador Semântico
# **Tempo sugerido: 15 minutos | Valor: 25 pontos**
#
# ### Enunciado
#
# A terceira funcionalidade é o **Comparador Semântico** — ela mede
# automaticamente o quanto dois conceitos estão relacionados.
#
# Escreva um código que compare a palavra `'school'` com cada palavra da lista abaixo
# e apresente os resultados de forma organizada:
#
# ```python
# palavras_comparar = ['university', 'hospital', 'library', 'car', 'apple']
# ```
#
# Seu código deve:
#
# 1. Calcular a **similaridade** entre `'school'` e cada palavra da lista
# 2. Exibir os resultados em uma **tabela formatada** com:
#    - O par de palavras
#    - O valor numérico da similaridade (4 casas decimais)
#    - Uma **barra visual** proporcional ao valor (use o caractere `█`)
#    - Uma classificação: `🟢 Alta`, `🟡 Média` ou `🔴 Baixa`
# 3. Ao final, indique qual palavra é **mais similar** e qual é **menos similar** a `'school'`
# 4. Escreva sua **interpretação** dos resultados como comentário no código
#
# **Saída esperada:**
# ```
# 📊 Comparador Semântico — escola × ?
# ──────────────────────────────────────────────────
# school × university  0.3333  ████████░░  🟢 Alta
# school × hospital    0.1667  ████░░░░░░  🟡 Média
# ...
# ──────────────────────────────────────────────────
# 🏆 Mais similar : university (0.3333)
# 📉 Menos similar: apple      (0.0400)
# ```
#
# > 💡 **Dica 1:** use `wn.synsets('school')[0].path_similarity(wn.synsets('university')[0])`
# > 💡 **Dica 2:** `'█' * int(sim * 20)` gera uma barra de tamanho proporcional
# > 💡 **Dica 3:** `'░' * (20 - int(sim * 20))` preenche o restante da barra

# %%
# ✏️ SEU CÓDIGO AQUI — Tarefa 3
# ─────────────────────────────────────────────────────────────
# Dica 1: defina um limiar para classificar Alta/Média/Baixa
#         ex: sim > 0.25 → Alta | sim > 0.10 → Média | resto → Baixa
# Dica 2: use uma lista de tuplas para guardar os resultados
#         e ordená-los com sorted() se quiser exibir do maior pro menor
# ─────────────────────────────────────────────────────────────

palavras_comparar = ['university', 'hospital', 'library', 'car', 'apple']

# seu código abaixo:

# %% [markdown]
# ---
# ## 📌 Tarefa 4 — Construtor de Grafo Temático
# **Tempo sugerido: 15 minutos | Valor: 25 pontos**
#
# ### Enunciado
#
# A quarta e última funcionalidade é o **Construtor de Grafo Temático** —
# ela gera automaticamente um grafo de conhecimento visual a partir de um tema.
#
# Você deve construir um grafo para o tema **"meios de transporte"**,
# usando `wn.synset('vehicle.n.01')` como ponto de partida.
#
# Seu código deve:
#
# 1. Criar um grafo com **2 níveis de profundidade** a partir de `vehicle.n.01`
#    (o nó raiz + seus hyponyms + os hyponyms dos hyponyms)
# 2. Limitar a **4 filhos por nó** (para não sobrecarregar o grafo)
# 3. Usar **cores diferentes** para cada nível:
#    - Nível 0 (raiz): cor à sua escolha
#    - Nível 1 (filhos): cor à sua escolha
#    - Nível 2 (netos): cor à sua escolha
# 4. Exibir o grafo com **título**, **legenda** e **arestas com setas**
# 5. Ao final, imprimir:
#    - Quantos **nós** o grafo possui
#    - Quantas **arestas** o grafo possui
#    - Qual nó tem **mais conexões** (maior grau)
#
# > 💡 **Dica 1:** use `nx.DiGraph()` para criar o grafo direcionado
# > 💡 **Dica 2:** `G.add_edge('pai', 'filho')` adiciona uma aresta
# > 💡 **Dica 3:** `nx.spring_layout(G, seed=42)` define o layout
# > 💡 **Dica 4:** `G.degree()` retorna o grau de cada nó
# > 💡 **Dica 5:** `synset.name().split('.')[0]` extrai só a palavra do nome do synset

# %%
# ✏️ SEU CÓDIGO AQUI — Tarefa 4
# ─────────────────────────────────────────────────────────────
# Estrutura sugerida:
#
# 1. Criar o grafo: G = nx.DiGraph()
#
# 2. Definir a raiz:
#    raiz = wn.synset('vehicle.n.01')
#
# 3. Percorrer os hyponyms com dois laços for:
#    for filho in raiz.hyponyms()[:4]:
#        G.add_edge(raiz_nome, filho_nome)
#        for neto in filho.hyponyms()[:4]:
#            G.add_edge(filho_nome, neto_nome)
#
# 4. Plotar com nx.draw_networkx_*
#
# 5. Calcular e exibir as estatísticas do grafo
# ─────────────────────────────────────────────────────────────

# %% [markdown]
# ---
# ## 🏁 Finalização e Reflexão
#
# Responda as perguntas abaixo **editando esta célula de texto** (clique duas vezes para editar):
#
# ---
#
# **1. Na Tarefa 1, quantos significados a palavra 'light' possui no WordNet?
# Qual foi o mais surpreendente para você e por quê?**
#
# _Sua resposta aqui_
#
# ---
#
# **2. Na Tarefa 3, o resultado de similaridade entre 'school' e 'library' (biblioteca)
# faz sentido para você? Justifique.**
#
# _Sua resposta aqui_
#
# ---
#
# **3. Olhando o grafo da Tarefa 4, qual nó ficou com mais conexões?
# Por que faz sentido esse nó ser o mais conectado?**
#
# _Sua resposta aqui_
#
# ---
#
# **4. Em qual aplicação do mundo real você usaria o Explorador Semântico
# que construiu neste laboratório? Descreva brevemente.**
#
# _Sua resposta aqui_
#
# ---
